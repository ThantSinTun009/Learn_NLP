# %% [markdown]
# # Parts of speech tagging

# %% [markdown]
# In many cases, NLP processing depends on determining the parts of speech of the words in the text.
#
# For example, in sentence classification, we sometimes use the **parts of speech of the words as a feature** that is input to the classifier.
#
# In this recipe, we will again consider the NLTK and spaCy algorithms.

# %% [markdown]
# > POS tagging helps NLP systems understand the structure and meaning of sentences.

# %%
import nltk
import spacy

# %%
# read text
filename= 'sherlock_holmes_1.txt'
file = open(filename, 'r', encoding='utf-8')
text = file.read()

# %%
# preprocess
text = text.replace('\n', ' ')
text
# Out:
# 'To Sherlock Holmes she is always _the_ woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position. He never spoke of the softer passions, save with a gibe and a sneer. They were admirable things for the observer—excellent for drawing the veil from men’s motives and actions. But for the trained reasoner to admit such intrusions into his own delicate and finely adjusted temperament was to introduce a distracting factor which might throw a doubt upon all his mental results. Grit in a sensitive instrument, or a crack in one of his own high-power lenses, would not be more disturbing than a strong
# ...

# %%
# initialize spacy engine: nlp pipeline
nlp = spacy.load('en_core_web_sm')
nlp

# %%
# Use the spaCy engine to process the text:
doc = nlp(text)
doc
# Out:
# To Sherlock Holmes she is always _the_ woman. I have seldom heard him mention her under any other name. In his eyes she eclipses and predominates the whole of her sex. It was not that he felt any emotion akin to love for Irene Adler. All emotions, and that one particularly, were abhorrent to his cold, precise but admirably balanced mind. He was, I take it, the most perfect reasoning and observing machine that the world has seen, but as a lover he would have placed himself in a false position. He never spoke of the softer passions, save with a gibe and a sneer. They were admirable things for the observer—excellent for drawing the veil from men’s motives and actions. But for the trained reasoner to admit such intrusions into his own delicate and finely adjusted temperament was to introduce a distracting factor which might throw a doubt upon all his mental results. Grit in a sensitive instrument, or a crack in one of his own high-power lenses, would not be more disturbing than a strong 
# ...

# %%
# extract words
words = [token.text for token in doc]

# extract POS tags
pos = [token.pos_ for token in doc]

# zip words and pos tags
word_pos_tuples = list(zip(words, pos))
word_pos_tuples
# Out:
# [('To', 'ADP'),
#  ('Sherlock', 'PROPN'),
#  ('Holmes', 'PROPN'),
#  ('she', 'PRON'),
#  ('is', 'AUX'),
#  ('always', 'ADV'),
#  ('_', 'PROPN'),
#  ('the', 'DET'),
#  ('_', 'PROPN'),
#  ('woman', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('I', 'PRON'),
#  ('have', 'AUX'),
#  ('seldom', 'ADV'),
#  ('heard', 'VERB'),
#  ('him', 'PRON'),
#  ('mention', 'VERB'),
#  ('her', 'PRON'),
#  ('under', 'ADP'),
#  ('any', 'DET'),
#  ('other', 'ADJ'),
#  ('name', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('In', 'ADP'),
#  ('his', 'DET'),
#  ('eyes', 'NOUN'),
#  ('she', 'PRON'),
#  ('eclipses', 'VERB'),
#  ('and', 'CCONJ'),
#  ('predominates', 'VERB'),
#  ('the', 'DET'),
#  ('whole', 'NOUN'),
#  ('of', 'ADP'),
#  ('her', 'DET'),
#  ('sex', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('It', 'PRON'),
#  ('was', 'AUX'),
#  ('not', 'PART'),
#  ('that', 'SCONJ'),
#  ('he', 'PRON'),
#  ('felt', 'VERB'),
#  ('any', 'DET'),
#  ('emotion', 'NOUN'),
#  ('akin', 'ADJ'),
#  ('to', 'PART'),
#  ('love', 'NOUN'),
#  ('for', 'ADP'),
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### NLTK package

# %%
import nltk

filename = "sherlock_holmes_1.txt"
file = open(filename, "r", encoding="utf-8")
text = file.read()

text = text.replace("\n", " ")

# %%
words = nltk.tokenize.word_tokenize(text)

words_with_pos = nltk.pos_tag(words)
words_with_pos
# Out:
# [('To', 'TO'),
#  ('Sherlock', 'NNP'),
#  ('Holmes', 'NNP'),
#  ('she', 'PRP'),
#  ('is', 'VBZ'),
#  ('always', 'RB'),
#  ('_the_', 'JJ'),
#  ('woman', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('seldom', 'VBN'),
#  ('heard', 'RB'),
#  ('him', 'PRP'),
#  ('mention', 'VB'),
#  ('her', 'PRP'),
#  ('under', 'IN'),
#  ('any', 'DT'),
#  ('other', 'JJ'),
#  ('name', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('his', 'PRP$'),
#  ('eyes', 'NNS'),
#  ('she', 'PRP'),
#  ('eclipses', 'VBZ'),
#  ('and', 'CC'),
#  ('predominates', 'VBZ'),
#  ('the', 'DT'),
#  ('whole', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('sex', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('felt', 'VBD'),
#  ('any', 'DT'),
#  ('emotion', 'NN'),
#  ('akin', 'NN'),
#  ('to', 'TO'),
#  ('love', 'VB'),
#  ('for', 'IN'),
#  ('Irene', 'NNP'),
#  ('Adler', 'NNP'),
#  ('.', '.'),
#  ('All', 'DT'),
#  ('emotions', 'NNS'),
#  (',', ','),
# ...

# %% [markdown]
# ---
